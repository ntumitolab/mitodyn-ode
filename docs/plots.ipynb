# %% [markdown]
# # Julia Plots.jl

# %%
using Plots
pyplot()
# Out:
# ┌ Info: Installing matplotlib via the Conda matplotlib package...
# └ @ PyCall /home/runner/.julia/packages/PyCall/3fwVL/src/PyCall.jl:711
# ┌ Info: Running `conda install -q -y matplotlib` in root environment
# └ @ Conda /home/runner/.julia/packages/Conda/sNGum/src/Conda.jl:128
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /home/runner/.julia/conda/3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       he6710b0_2         375 KB
#     cycler-0.10.0              |   py39h06a4308_0          16 KB
#     dbus-1.13.18               |       hb2f20db_0         504 KB
#     expat-2.4.1                |       h2531618_2         168 KB
#     fontconfig-2.13.1          |       h6c09931_0         250 KB
# ...

# %%
plot(Plots.fakedata(50, 5), w = 3)
